# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name: Azeem Haider")
print("Father Name: Zaheer Mirza")
print("Date of Birth: 08-04-1992")
# Out:
# Name: Azeem Haider
# Father Name: Zaheer Mirza
# Date of Birth: 08-04-1992

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Azeem Haider"
age = 25
profession = "Software Engineer"
city = "Karachi"

print("My Name is :", name)
print("Age:", age)
print("Profession:", profession)
print("City:", city)
# Out:
# My Name is : Azeem Haider
# Age: 25
# Profession: Software Engineer
# City: Karachi

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 10
b = 3

print("Addition:", a + b)        
print("Subtraction:", a - b)     
print("Multiplication:", a * b)  
print("Division:", a / b)      
print("Floor Division:", a // b) 
print("Modulus:", a % b)         
print("Exponent:", a ** b)      

print("a == b:", a == b)   
print("a != b:", a != b)   
print("a > b:", a > b)     
print("a < b:", a < b)     
print("a >= b:", a >= b)   
print("a <= b:", a <= b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponent: 1000
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Marks out of 100

english = 85
islamiat = 90
maths = 80

# Total marks

total_marks = 300

# Obtained marks
obtained_marks = english + islamiat + maths

# Calculate percentage
percentage = (obtained_marks / total_marks) * 100

print("English:", english)
print("Islamiat:", islamiat)
print("Maths:", maths)
print("Total Marks:", total_marks)
print("Percentage:", percentage, "%")
# Out:
# English: 85
# Islamiat: 90
# Maths: 80
# Total Marks: 300
# Percentage: 85.0 %
